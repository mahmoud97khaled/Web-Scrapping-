# %%
import requests
import csv
from bs4 import BeautifulSoup

# %%
url='https://books.toscrape.com/index.html'
soup=BeautifulSoup(requests.get(url).text,'html.parser')

# %%
domain='https://books.toscrape.com/'
fiction_url=domain+soup.find('ul',attrs={'class':''}).find_all('li')[8].find('a').get('href')
print(domain+soup.find('ul',attrs={'class':''}).find_all('li')[8].find('a').get('href'))
# Out:
# https://books.toscrape.com/catalogue/category/books/fiction_10/index.html

# %%
soup_cat=BeautifulSoup(requests.get(fiction_url).text,'html.parser')
soup_cat
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     Fiction |
#      Books to Scrape - Sandbox
#
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
#
# " name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
category_name=soup_cat.find('title').get_text().strip().split('|')[0]
category_name
# Out:
# 'Fiction '

# %%
rates_dic={'Zero':0,'One':1,'Two':2,'Three':3,'Four':4,'Five':5}
rates_dic[soup_cat.find_all('article',attrs={'class':'product_pod'})[1].find('p').get('class')[1]]
# Out:
# 5

# %%
soup_cat.find_all('article',attrs={'class':'product_pod'})[1].find('h3').find('a').get('title')
# Out:
# 'Private Paris (Private #10)'

# %%
float(soup_cat.find_all('article',attrs={'class':'product_pod'})[1].find('div',attrs={'class':'product_price'}).find('p').get_text()[2:])
# Out:
# 47.61

# %%
from functools import reduce



reduce(lambda a,b:a+'/'+b,fiction_url.split('/')[:-1])+'/'
# Out:
# 'https://books.toscrape.com/catalogue/category/books/fiction_10/'

# %%
soup_cat.find('li',attrs={'class':'next'}).find('a').get('href')
# Out:
# 'page-2.html'

# %%
rates_dic={'Zero':0,'One':1,'Two':2,'Three':3,'Four':4,'Five':5}



with open('books.csv','w',encoding='utf-8',newline='') as f:
    writer=csv.writer(f)
    writer.writerow(['Book_name','Price','Rate','Category'])
    category_name=soup_cat.find('title').get_text().strip().split('|')[0]
    for article in soup_cat.find_all('article',attrs={'class':'product_pod'}):
        Book_name=article.find('h3').find('a').get('title')
        Price=float(article.find('div',attrs={'class':'product_price'}).find('p').get_text()[2:])
        Rate=rates_dic[article.find('p').get('class')[1]]
        writer.writerow([Book_name,Price,Rate,category_name])
    while soup_cat.find('li',attrs={'class':'next'}):
        new_page_url=reduce(lambda a,b:a+'/'+b,fiction_url.split('/')[:-1])+'/'+soup_cat.find('li',attrs={'class':'next'}).find('a').get('href')
        soup_cat=BeautifulSoup(requests.get(new_page_url).text,'html.parser')
        for article in soup_cat.find_all('article',attrs={'class':'product_pod'}):
            Book_name=article.find('h3').find('a').get('title')
            Price=float(article.find('div',attrs={'class':'product_price'}).find('p').get_text()[2:])
            Rate=rates_dic[article.find('p').get('class')[1]]
            writer.writerow([Book_name,Price,Rate,category_name])

# %%
import pandas as pd
df=pd.read_csv('books.csv')
df.shape
# Out:
# (65, 4)

# %%
df.head()
# Out:
#                                            Book_name  Price  Rate  Category
# 0                                         Soumission  50.10     1  Fiction
# 1                        Private Paris (Private #10)  47.61     5  Fiction
# 2                       We Love You, Charlie Freeman  50.27     5  Fiction
# 3                                             Thirst  17.27     5  Fiction
# 4  The Murder That Never Was (Forensic Instincts #5)  54.11     3  Fiction
